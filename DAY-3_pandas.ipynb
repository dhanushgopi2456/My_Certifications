# %%
#PANDAS
import pandas as pd

# %%
#Series - Syntax = pd.Series.(column,index)   -->   #index   columns
# it contains indexes and columns and prints  -->   #  0     name/keys
a=["Jwalitha","Ramya","Durga","Jahnavi","Lahari","Sunny","Dhanush"]
r=pd.Series(a,index=[67,43,44,89,34,45,23]) #using arrays
print(r)
# Out:
# 67    Jwalitha
# 43       Ramya
# 44       Durga
# 89     Jahnavi
# 34      Lahari
# 45       Sunny
# 23     Dhanush
# dtype: object

# %%
#read_csv File
#loading csv
#two techiniques 1)rows and columns and other is2) we fill values in place of null
dia = pd.read_csv("/diabetcsv (1).csv")
dia
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
#grades
grade= pd.read_csv("/grades.txt")
grade
# Out:
#    Names Initials SEM1 SEM2 SEM3 Grade
# 0                  Joe K 9.8 10 9.9 A+
# 1               Rajesh M 8.9 9.1 9.3 A
# 2               Kissan V 9.9 9.3 9.2 A
# 3                   Mary N 7.7 8 7.1 B
# 4                Jeen K 9.8 9.1 9.9 A+
# 5                  Raj M 8.9 9.1 9.3 A
# 6                 Hassan V 9.9 9 9.2 A
# 7                   Mari N 7.7 8 7.1 B
# 8                Jess K 9.8 9.1 9.9 A+
# 9                 Rajini M 7 9.1 9.3 A
# 10               Kiran V 9.9 9.3 9.2 A
# 11                  Maya N 7.7 8 7.1 B
# 12              Jolin K 9.8 9.1 9.9 A+
# 13                  Riya M 8 9.1 9.3 A
# 14                Sana V 9.9 9.3 9.2 A
# 15                    Mark N 7.7 8 7 B

# %%
grade= pd.read_csv("/content/demodt.txt")
grade
# Out:
#    State  Literacy  Cleanliness  Crime_Rate  Good
# 0      A        92           90          54     0
# 1      B        56           67          50     1
# 2      C        78           85          62     0
# 3      D        63           72          48     1
# 4      E        85           79          55     0
# 5      F        71           68          58     0
# 6      G        80           83          51     0
# 7      H        67           74          47     1
# 8      I        89           88          53     0
# 9      J        58           65          49     1
# 10     K        82           81          60     0
# 11     L        75           78          57     0
# 12     M        69           70          46     1
# 13     N        87           86          52     0
# 14     O        61           63          45     1
# 15     P        93           91          56     0
# 16     Q        55           66          61     0
# 17     R        76           77          59     0
# ...

# %%
#read_excel File
diaxl=pd.read_excel("/content/diabetes (1).xlsx")
diaxl
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
diaxls= pd.read_excel("/content/diabetes (1).xlsx",sheet_name='dora')
diaxls
# Out:
#   Dead Alive
# 0  yes    no
# 1  yes    no
# 2  yes    no
# 3  yes    no
# 4  yes    no

# %%
#describe()- it describes the each and every field (describing a data frame)
diaxl.describe()
# Out:
#              preg        plas        pres        skin        insu        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age
# count  768.000000  768.000000
# mean     0.471876   33.240885
# std      0.331329   11.760232
# min      0.078000   21.000000
# 25%      0.243750   24.000000
# 50%      0.372500   29.000000
# 75%      0.626250   41.000000
# ...

# %%
# shape
df=pd.read_csv("/content/demodt.txt")
print(df.shape)
print(df.shape[0])
# Out:
# (26, 5)
# 26

# %%
df=pd.read_csv("/content/grades_withnulls.csv")
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
print(df.isnull()) # if we have the true that is null value data missing
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
#sum function sum()- it shows the column wise null values
print(df.isnull().sum())
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
#drop function
# save changes in another data frame it is not reflected to oringinal data frame
# df.dropna()
# for saving in original data frame we use inplace
df.dropna()
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df1 # no changes reflected
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
#inplace function
df1=pd.read_csv("/content/grades_withnulls.csv")
df1.dropna(inplace=True) #save changes in original data frame
df1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
#2)save the changes in another variable
df2=pd.read_csv("/content/grades_withnulls.csv")
mdf2=df2.dropna()
mdf2
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
#fillna function - it replaces the value in place of null
df2=pd.read_csv("/content/grades_withnulls.csv")
df2.fillna(555) #But changes are not saved
df2
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df2=pd.read_csv("/content/grades_withnulls.csv")
df2.fillna(555,inplace=True) #changes are saved in original data frame
df2
# Out:
#      Names Initials   SEM1  SEM2   SEM3 Grade  Placed
# 0      Joe        K    9.8  10.0    9.9    A+       1
# 1   Rajesh        M    8.9   9.1    9.3     A       1
# 2   Kissan        V    9.9   9.8   10.0     A       0
# 3     Mary        N    7.7   8.0  555.0     B       0
# 4     Jeen        K    9.8   9.1    9.9    A+       1
# 5      Raj        M    8.9   9.1    9.3     A       1
# 6   Hassan        V    9.9   9.0    9.2     A       1
# 7     Mari        N    7.7   8.0    7.1     B       1
# 8     Jess        K  555.0   9.1    9.9    A+       1
# 9   Rajini        M  555.0   9.1    9.3     A       0
# 10   Kiran        V  555.0   9.3    9.2     A       0
# 11    Maya        N    7.7   8.0    7.1     B       0
# 12   Jolin        K    9.8   9.1    9.9    A+       1
# 13  Rajesh        M    8.9   9.1    9.3     A       1
# 14    Riya        M    9.3   9.9   10.0     A       1
# 15    Sana        V    9.9   9.3    9.2     A       0
# ...

# %%
#fillna function - it replaces the value in place of null
df2=pd.read_csv("/content/grades_withnulls.csv")
mf2=df2.fillna(555) # changes saved using another data variable
mf2
# Out:
#      Names Initials   SEM1  SEM2   SEM3 Grade  Placed
# 0      Joe        K    9.8  10.0    9.9    A+       1
# 1   Rajesh        M    8.9   9.1    9.3     A       1
# 2   Kissan        V    9.9   9.8   10.0     A       0
# 3     Mary        N    7.7   8.0  555.0     B       0
# 4     Jeen        K    9.8   9.1    9.9    A+       1
# 5      Raj        M    8.9   9.1    9.3     A       1
# 6   Hassan        V    9.9   9.0    9.2     A       1
# 7     Mari        N    7.7   8.0    7.1     B       1
# 8     Jess        K  555.0   9.1    9.9    A+       1
# 9   Rajini        M  555.0   9.1    9.3     A       0
# 10   Kiran        V  555.0   9.3    9.2     A       0
# 11    Maya        N    7.7   8.0    7.1     B       0
# 12   Jolin        K    9.8   9.1    9.9    A+       1
# 13  Rajesh        M    8.9   9.1    9.3     A       1
# 14    Riya        M    9.3   9.9   10.0     A       1
# 15    Sana        V    9.9   9.3    9.2     A       0
# ...

# %%
#using mean to replace the null values
df3=pd.read_csv("/content/grades_withnulls.csv")
mv=df3['SEM1'].mean()
df3.fillna(mv,inplace=True)
df3
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %%
#accessing  the data
#iloc = observes only integer location,accept index number
#loc=field names,index
#Syntax= mydf.loc[index] --->accessing rows
#mydf.loc[st:stop]  --->ranges of rows
#mydf.loc[r_ind,colname] ---> accessing rows and columns
mydf=pd.read_csv("/grades_withnulls.csv")
mydf.loc[0] #first record (rows)
# Out:
# Names        Joe
# Initials       K
# SEM1         9.8
# SEM2        10.0
# SEM3         9.9
# Grade         A+
# Placed         1
# Name: 0, dtype: object

# %%
mydf.loc[0:5]
# Out:
#     Names Initials  SEM1  SEM2  SEM3 GPA  Placed  Average Conduct
# 0     Joe        K   9.8  10.0   9.9  A+       1      9.9    Good
# 1  Rajesh        M   8.9   9.1   9.3   A       1      9.1    Good
# 2  Kissan        V   9.9   9.8  10.0   A       0      9.9    Good
# 3    Mary        N   7.7   8.0   NaN   B       0      NaN    Good
# 4    Jeen        K   9.8   9.1   9.9  A+       1      9.6    Good
# 5     Raj        M   8.9   9.1   9.3   A       1      9.1    Good

# %%
mydf.loc[5:7,'SEM1']
# Out:
# 5    8.9
# 6    9.9
# 7    7.7
# Name: SEM1, dtype: float64

# %%
#accesing using index function
mydf[mydf.index==7] # display the 7 index record
# Out:
#   Names Initials  SEM1  SEM2  SEM3 GPA  Placed  Average Conduct
# 7  Mari        N   7.7   8.0   7.1   B       1      7.6    Good

# %%
print("Accessing specific row and column")
print(mydf.loc[mydf.index==7,"Grade"])
# Out:
# Accessing specific row and column
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Grade'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
mydf.iloc[10:12,0:2] # access both rows and column indexes (only accept index numbers)
# Out:
#     Names Initials
# 10  Kiran        V
# 11   Maya        N

# %%
mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 GPA  Placed   Average Conduct
# 0      Joe        K   9.8  10.0   9.9  A+       1  9.900000    Good
# 1   Rajesh        M   8.9   9.1   9.3   A       1  9.100000    Good
# 2   Kissan        V   9.9   9.8  10.0   A       0  9.900000    Good
# 3     Mary        N   7.7   8.0   NaN   B       0       NaN    Good
# 4     Jeen        K   9.8   9.1   9.9  A+       1  9.600000    Good
# 5      Raj        M   8.9   9.1   9.3   A       1  9.100000    Good
# 6   Hassan        V   9.9   9.0   9.2   A       1  9.366667    Good
# 7     Mari        N   7.7   8.0   7.1   B       1  7.600000    Good
# 8     Jess        K   NaN   9.1   9.9  A+       1       NaN    Good
# 9   Rajini        M   NaN   9.1   9.3   A       0       NaN    Good
# 10   Kiran        V   NaN   9.3   9.2   A       0       NaN    Good
# 11    Maya        N   7.7   8.0   7.1   B       0  7.600000    Good
# 12   Jolin        K   9.8   9.1   9.9  A+       1  9.600000    Good
# ...

# %%
mydf[mydf.SEM2==10] #print only 10 points in SEM2
mydf[mydf.Grade=='A'] #print only grade A students in mydf table
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0

# %%
#Print records to score 9.3 in the SEM3
mydf[mydf.SEM3==9.3]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 13  Rajesh        M   8.9   9.1   9.3     A       1

# %%
#loc[index,columns]
mydf.loc[mydf['SEM1']>9.8,['Names']]  #print at the location SEM1 in mydf which is greater than 9.8
                                      #['Names'] print only names
# Out:
#      Names
# 2   Kissan
# 6   Hassan
# 15    Sana

# %%
#print the grades of students who scored more than 9.7 in sem3
mydf.loc[mydf['SEM3']>9.7,['Grade']] # loc[index,column]
#accesing the records with sem>9.7 but printing only grades
# Out:
#    Grade
# 0     A+
# 2      A
# 4     A+
# 8     A+
# 12    A+
# 14     A

# %%
#Drop duplicate -function it removes the duplicate records in file
mydf.drop_duplicates() #Syntax- tablename.drop_duplicates( )
#but changes are not reflected
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
mydf.drop_duplicates(inplace=True)
mydf # changes applied to original table
# Out:
#      Names Initials  SEM1  SEM2  SEM3 GPA  Placed   Average Conduct
# 0      Joe        K   9.8  10.0   9.9  A+       1  9.900000    Good
# 1   Rajesh        M   8.9   9.1   9.3   A       1  9.100000    Good
# 2   Kissan        V   9.9   9.8  10.0   A       0  9.900000    Good
# 3     Mary        N   7.7   8.0   NaN   B       0       NaN    Good
# 4     Jeen        K   9.8   9.1   9.9  A+       1  9.600000    Good
# 5      Raj        M   8.9   9.1   9.3   A       1  9.100000    Good
# 6   Hassan        V   9.9   9.0   9.2   A       1  9.366667    Good
# 7     Mari        N   7.7   8.0   7.1   B       1  7.600000    Good
# 8     Jess        K   NaN   9.1   9.9  A+       1       NaN    Good
# 9   Rajini        M   NaN   9.1   9.3   A       0       NaN    Good
# 10   Kiran        V   NaN   9.3   9.2   A       0       NaN    Good
# 11    Maya        N   7.7   8.0   7.1   B       0  7.600000    Good
# 12   Jolin        K   9.8   9.1   9.9  A+       1  9.600000    Good
# ...

# %%
#head function- it shows first 5 records
mydf.head() # by default it displays first 5 records
mydf.head(7) # display first 7 records
# Out:
#     Names Initials  SEM1  SEM2  SEM3 GPA  Placed   Average Conduct
# 0     Joe        K   9.8  10.0   9.9  A+       1  9.900000    Good
# 1  Rajesh        M   8.9   9.1   9.3   A       1  9.100000    Good
# 2  Kissan        V   9.9   9.8  10.0   A       0  9.900000    Good
# 3    Mary        N   7.7   8.0   NaN   B       0       NaN    Good
# 4    Jeen        K   9.8   9.1   9.9  A+       1  9.600000    Good
# 5     Raj        M   8.9   9.1   9.3   A       1  9.100000    Good
# 6  Hassan        V   9.9   9.0   9.2   A       1  9.366667    Good

# %%
#tail function-
mydf.tail() # by default it displays last 5 records
mydf.tail(7) # display last 7 records
# Out:
#      Names Initials  SEM1  SEM2  SEM3 GPA  Placed   Average Conduct
# 10   Kiran        V   NaN   9.3   9.2   A       0       NaN    Good
# 11    Maya        N   7.7   8.0   7.1   B       0  7.600000    Good
# 12   Jolin        K   9.8   9.1   9.9  A+       1  9.600000    Good
# 13  Rajesh        M   8.9   9.1   9.3   A       1  9.100000    Good
# 14    Riya        M   9.3   9.9  10.0   A       1  9.733333    Good
# 15    Sana        V   9.9   9.3   9.2   A       0  9.466667    Good
# 16    Mark        N   7.7   8.0   7.0   B       0  7.566667    Good

# %%
#column1
colnames=mydf.columns #view column names !
print(colnames)
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'GPA', 'Placed', 'Average',
#        'Conduct'],
#       dtype='object')

# %%
#column1 type cast to list
collist=list(mydf.columns) #view column names in list !
print(collist)
# Out:
# ['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'GPA', 'Placed', 'Average', 'Conduct']

# %%
#Rename a column 1 renames the column but reflected to original table using inplace
#
mydf.rename(columns={'Grade':'GPA'},inplace=True)
mydf.columns
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'GPA', 'Placed', 'Average',
#        'Conduct'],
#       dtype='object')

# %%
#Creating a new column !
#Syntax['new col']=value
mydf["Conduct"]="Good"
mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed   Average Conduct
# 0      Joe        K   9.8  10.0   9.9    A+       1  9.900000    Good
# 1   Rajesh        M   8.9   9.1   9.3     A       1  9.100000    Good
# 2   Kissan        V   9.9   9.8  10.0     A       0  9.900000    Good
# 3     Mary        N   7.7   8.0   NaN     B       0       NaN    Good
# 4     Jeen        K   9.8   9.1   9.9    A+       1  9.600000    Good
# 5      Raj        M   8.9   9.1   9.3     A       1  9.100000    Good
# 6   Hassan        V   9.9   9.0   9.2     A       1  9.366667    Good
# 7     Mari        N   7.7   8.0   7.1     B       1  7.600000    Good
# 8     Jess        K   NaN   9.1   9.9    A+       1       NaN    Good
# 9   Rajini        M   NaN   9.1   9.3     A       0       NaN    Good
# 10   Kiran        V   NaN   9.3   9.2     A       0       NaN    Good
# 11    Maya        N   7.7   8.0   7.1     B       0  7.600000    Good
# ...

# %%
#create a new column average with average values of sem1 sem2 sem3

mydf["Average"]=(mydf['SEM1']+mydf['SEM2']+mydf['SEM3'])/3
mydf
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed   Average
# 0      Joe        K   9.8  10.0   9.9    A+       1  9.900000
# 1   Rajesh        M   8.9   9.1   9.3     A       1  9.100000
# 2   Kissan        V   9.9   9.8  10.0     A       0  9.900000
# 3     Mary        N   7.7   8.0   NaN     B       0       NaN
# 4     Jeen        K   9.8   9.1   9.9    A+       1  9.600000
# 5      Raj        M   8.9   9.1   9.3     A       1  9.100000
# 6   Hassan        V   9.9   9.0   9.2     A       1  9.366667
# 7     Mari        N   7.7   8.0   7.1     B       1  7.600000
# 8     Jess        K   NaN   9.1   9.9    A+       1       NaN
# 9   Rajini        M   NaN   9.1   9.3     A       0       NaN
# 10   Kiran        V   NaN   9.3   9.2     A       0       NaN
# 11    Maya        N   7.7   8.0   7.1     B       0  7.600000
# 12   Jolin        K   9.8   9.1   9.9    A+       1  9.600000
# 13  Rajesh        M   8.9   9.1   9.3     A       1  9.100000
# ...

# %%
mydf['SEM1'].plot.line() # diplaying the SEM1 column table in graph
# Out:
# <Axes: >

# %%
#Subplots
mydf[['SEM1','SEM2']].plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
mydf.plot.line(subplots=True) #display all subplots
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
mydf.plot(kind="scatter",x="Average",y="Names")
# Out:
# <Axes: xlabel='Average', ylabel='Names'>

# %%
mydf.plot(kind="hist",x="Names",y="Average") # xaxis should be count ,yaxis- it should be numeric data type while using hist
# Out:
# <Axes: ylabel='Frequency'>

# %%
mydf.to_csv("mydf.csv")
